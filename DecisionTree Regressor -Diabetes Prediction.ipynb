# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes

# %%
dataset = load_diabetes()

# %%
print(dataset['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %% [markdown]
# ## data : 10 features
# ## target : output - has a continuous value because its regression problem
#
# ## independent features
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
#       - s6      glu, blood sugar level

# %%
X=pd.DataFrame(dataset.data,columns=['age','sex','bmi','bp','s1','s2','s3','s4','s5','s6'])

# %%
## independent feature
X
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
# dependent feature
y=dataset['target']

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
X.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
## train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)

# %%
## check correlation
X_train.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.197408  0.198359  0.394903  0.238375  0.192920 -0.128403
# sex  0.197408  1.000000  0.108261  0.221914  0.057674  0.180315 -0.379464
# bmi  0.198359  0.108261  1.000000  0.356324  0.226047  0.248146 -0.395021
# bp   0.394903  0.221914  0.356324  1.000000  0.238295  0.165632 -0.192505
# s1   0.238375  0.057674  0.226047  0.238295  1.000000  0.872781  0.006313
# s2   0.192920  0.180315  0.248146  0.165632  0.872781  1.000000 -0.265114
# s3  -0.128403 -0.379464 -0.395021 -0.192505  0.006313 -0.265114  1.000000
# s4   0.227110  0.324882  0.412826  0.249141  0.559626  0.684840 -0.754616
# s5   0.314151  0.150956  0.435505  0.420236  0.566312  0.325759 -0.370523
# s6   0.351570  0.193322  0.358273  0.368882  0.356280  0.315890 -0.297055
#
#            s4        s5        s6
# age  0.227110  0.314151  0.351570
# sex  0.324882  0.150956  0.193322
# bmi  0.412826  0.435505  0.358273
# ...

# %%
## heatmap for showing corr
plt.figure(figsize=(15,10))
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <Axes: >

# %%
## Apply Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
treeRegressor=DecisionTreeRegressor()
treeRegressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
## Hyper paraneter tuning
params={
    'criterion':['squared_error','friedman_mse','absolute_error'],
    'splitter': ['best','random'],
    'max_depth': [1,2,3,4,5,10,15,20,25],
    'max_features':['auto','sqrt','log2']
    }

# %%
params
# Out:
# {'criterion': ['squared_error', 'friedman_mse', 'absolute_error'],
#  'splitter': ['best', 'random'],
#  'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#  'max_features': ['auto', 'sqrt', 'log2']}

# %%
from sklearn.model_selection import GridSearchCV
regressor=DecisionTreeRegressor()
grid=GridSearchCV(regressor,param_grid=params,cv=5,scoring='neg_mean_squared_error')

# %%
grid.fit(X_train,y_train)
# Out:
# C:\Users\savig\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 270 fits failed out of a total of 810.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 270 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\savig\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\savig\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\savig\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
grid.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_depth': 4,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
y_pred=grid.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.3796293180364849
# 48.3491538395701
# 3925.5016324650855

# %%
## check with respect to other params in new model
newmodel=DecisionTreeRegressor(criterion='friedman_mse',max_depth=4,max_features='log2',splitter='random')
newmodel.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=4,
#                       max_features='log2', splitter='random')

# %%
## visualize decision tree
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(newmodel,filled=True)
# Out:
# [Text(0.5431034482758621, 0.9, 'x[3] <= 0.026\nfriedman_mse = 5757.456\nsamples = 309\nvalue = 152.738'),
#  Text(0.27586206896551724, 0.7, 'x[7] <= 0.039\nfriedman_mse = 4732.129\nsamples = 220\nvalue = 134.873'),
#  Text(0.13793103448275862, 0.5, 'x[6] <= -0.038\nfriedman_mse = 4318.662\nsamples = 193\nvalue = 128.031'),
#  Text(0.06896551724137931, 0.3, 'x[0] <= 0.069\nfriedman_mse = 6427.671\nsamples = 23\nvalue = 167.739'),
#  Text(0.034482758620689655, 0.1, 'friedman_mse = 6673.399\nsamples = 22\nvalue = 166.318'),
#  Text(0.10344827586206896, 0.1, 'friedman_mse = 0.0\nsamples = 1\nvalue = 199.0'),
#  Text(0.20689655172413793, 0.3, 'x[4] <= 0.1\nfriedman_mse = 3791.142\nsamples = 170\nvalue = 122.659'),
#  Text(0.1724137931034483, 0.1, 'friedman_mse = 3680.825\nsamples = 169\nvalue = 121.775'),
#  Text(0.2413793103448276, 0.1, 'friedman_mse = 0.0\nsamples = 1\nvalue = 272.0'),
# ...

# %%
y_pred_new=newmodel.predict(X_test)

# %%
print(r2_score(y_test,y_pred_new))
print(mean_absolute_error(y_test,y_pred_new))
print(mean_squared_error(y_test,y_pred_new))
# Out:
# 0.26952303033134417
# 55.309214594928875
# 4622.2180065580515
